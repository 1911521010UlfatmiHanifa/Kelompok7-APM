# %% [markdown]
# <a href="https://colab.research.google.com/github/1911521010UlfatmiHanifa/Kelompok7-APM/blob/main/AlgoC45_Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORT LIBRARY
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#library input data
from sklearn.datasets import load_breast_cancer
#library pre-processing
from sklearn import preprocessing
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
#library evaluasi
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
#library visualisasi
import graphviz
import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files/Graphviz/bin/'

#MENAMPILKAN DATASET
dataset = pd.read_csv('data.csv')
dataset
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
#MENGECEK NILAI NULL DAN OUTLIER DATA
print(dataset.info())
print(dataset.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
#INPUT DATA
bc = load_breast_cancer()
features = bc['data']
target = bc['target']

# %%
#PRE PROCESSING
#Data Cleaning
imputer1 = SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer1.fit(features)
SimpleImputer()
features = imputer1.transform(features)
#Data Training dan Testing
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size=0.25, random_state=0)
#Feature Scalling
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
#PROCESSING
#classifier modelling
model = tree.DecisionTreeClassifier(random_state=0, max_depth=None, min_samples_split=2,
                                    min_samples_leaf=1)
#model fitting
clf = model.fit(x_train, y_train)
#model prediction
y_pred = model.predict(x_test)

# %%
#EVALUATION
#confusion matrix dan akurasi
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix :")
print(cm)
akurasi = classification_report(y_test,y_pred)
print("Akurasi          :")
print(akurasi)
akurasi1 = accuracy_score(y_test,y_pred)
print("Tingkat Akurasi  : ",(akurasi1*100),"%")
# Out:
# Confusion Matrix :
# [[50  3]
#  [14 76]]
# Akurasi          :
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85        53
#            1       0.96      0.84      0.90        90
#
#     accuracy                           0.88       143
#    macro avg       0.87      0.89      0.88       143
# weighted avg       0.90      0.88      0.88       143
#
# Tingkat Akurasi  :  88.11188811188812 %

# %%
#RESULT VISUALIZATION
dot_data = tree.export_graphviz(model, out_file=None, max_depth=None,
                                feature_names=None, class_names=None, filled=True)
graph = graphviz.Source(dot_data)
graph.view()
# Out:
# 'Source.gv.pdf'
